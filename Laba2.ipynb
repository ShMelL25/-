# %% [markdown]
# Использование Pandas
#
# Описание работы
#
# Данная работа посвящена использованию Pandas для анализа данных. В работе будут использоваться источники данных для анализа, взятые с портала data.gov.ru («Открытые данные России»). В частности, используется набор данных «Государственный реестр сертифицированных средств защиты информации» (https://data.gov.ru/opendata/7701350013-reesszi). Предстоит ответить на ряд вопросов используя этот набор данных.

# %% [markdown]
# 1. Выполнить загрузку CSV-файла в память посредством Pandas.

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/data-20220204T1151-structure-20220204T1151.csv')

# %%
df
# Out:
#      №\r\nсертификата Дата\r\nвнесения\r\nв реестр  \
# 0                17/1                   26.07.2002
# 1                21/2                   25.06.2013
# 2                27/1                   24.05.2005
# 3                32/1                   20.04.1996
# 4                32/2                   20.04.1996
# ...               ...                          ...
# 1919             4510                   14.01.2022
# 1920             4513                   19.01.2022
# 1921             4514                   20.01.2022
# 1922             4516                   25.01.2022
# 1923             4517                   02.02.2022
#
#      Срок\r\nдействия\r\nсертификата  \
# 0                         01.08.2020
# 1                         25.06.2019
# 2                         24.05.2020
# 3                         17.04.2021
# 4                         17.04.2021
# ...                              ...
# 1919                            #Н/Д
# 1920                      19.01.2027
# ...

# %% [markdown]
# 2. Показать список уникальных наименований документов, требованиям которых соответствуют представленные средства защиты информации.

# %%
df['Наименования документов, требованиям которых соответствует средство'].loc[df['Наименование\r\nсредства (шифр)']\
                                                                              .str.contains('система защиты информации') == True]\
                                                                              .unique()
# Out:
# array(['Соответствует требованиям документов: РД СВТ(2)',
#        'Соответствует требованиям документов: РД НДВ(3), РД СВТ(3), ТУ',
#        'Соответствует требованиям документов: РД НДВ(2), РД СВТ(3)',
#        'Соответствует требованиям документов: РД НДВ(3), РД СВТ(4)',
#        'Соответствует требованиям документов: РД НДВ(2), РД СВТ(3), ТУ',
#        'Соответствует требованиям документов: РД НДВ(4), РД СВТ(5)',
#        'Соответствует требованиям документов: РД МЭ(4), РД НДВ(4), РД СВТ(5), ТУ',
#        'Соответствует требованиям документов: Требования доверия(2), РД СВТ(3)',
#        'Соответствует требованиям документов: Требования доверия(4), Требования к СКН, Профиль защиты СКН(контроля подключения съемных машинных носителей информации четвертого класса защиты. ИТ.СКН.П4.ПЗ), РД СВТ(5)',
#        'Соответствует требованиям документов: РД НДВ(4), ТУ'],
#       dtype=object)

# %% [markdown]
# 3. Отобразить список наименований средств, соответствующих двум любым документам с требованиями по сертификации.

# %%
df.loc[((df['Наименования документов, требованиям которых соответствует средство'] == 'Соответствует требованиям документов: РД СВТ(2)') | 
        (df['Наименования документов, требованиям которых соответствует средство' ] == 'Соответствует требованиям документов: ТУ'))]
# Out:
#      №\r\nсертификата Дата\r\nвнесения\r\nв реестр  \
# 1                21/2                   25.06.2013
# 2                27/1                   24.05.2005
# 3                32/1                   20.04.1996
# 4                32/2                   20.04.1996
# 39             263/17                   03.08.2007
# ...               ...                          ...
# 1771             4354                   28.12.2020
# 1832             4418                   08.06.2021
# 1834             4420                   08.06.2021
# 1851             4439                   18.08.2021
# 1864             4452                   26.10.2021
#
#      Срок\r\nдействия\r\nсертификата  \
# 1                         25.06.2019
# 2                         24.05.2020
# 3                         17.04.2021
# 4                         17.04.2021
# 39                        03.08.2019
# ...                              ...
# 1771                      28.12.2025
# 1832                      08.06.2026
# ...

# %%
df_ = df.drop([1293, 1919])

# %% [markdown]
# 4. Показать наименования тех средств, которые имеют просроченные сертификаты (на момент выполнения задания).

# %%
df_['Срок\r\nдействия\r\nсертификата'] = df_['Срок\r\nдействия\r\nсертификата'].astype(dtype='datetime64')

# %%
x = df_[df_['Срок\r\nдействия\r\nсертификата'] <= '2022-11-22']

# %%
x
# Out:
#      №\r\nсертификата Дата\r\nвнесения\r\nв реестр  \
# 0                17/1                   26.07.2002
# 1                21/2                   25.06.2013
# 2                27/1                   24.05.2005
# 3                32/1                   20.04.1996
# 4                32/2                   20.04.1996
# ...               ...                          ...
# 1401             3973                   25.07.2018
# 1402             3974                   25.07.2018
# 1404             3976                   27.07.2018
# 1405             3977                   01.08.2018
# 1887             4475                   24.11.2021
#
#      Срок\r\nдействия\r\nсертификата  \
# 0                         2020-01-08
# 1                         2019-06-25
# 2                         2020-05-24
# 3                         2021-04-17
# 4                         2021-04-17
# ...                              ...
# 1401                      2021-07-25
# 1402                      2021-07-25
# ...

# %% [markdown]
# 5. Показать наименования тех средств, которые имеют просроченные сертификаты, но при этом обязаны оказывать поддержку (столбец «Информация об окончании срока технической поддержки, полученная от заявителя»).

# %%
x['Информация об окончании срока технической поддержки, полученная от заявителя'].isnull().value_counts()
# Out:
# True     905
# False    362
# Name: Информация об окончании срока технической поддержки, полученная от заявителя, dtype: int64

# %%
x['Информация об окончании срока технической поддержки, полученная от заявителя'] = x['Информация об окончании срока технической поддержки, полученная от заявителя'].fillna(0)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
x
# Out:
#      №\r\nсертификата Дата\r\nвнесения\r\nв реестр  \
# 0                17/1                   26.07.2002
# 1                21/2                   25.06.2013
# 2                27/1                   24.05.2005
# 3                32/1                   20.04.1996
# 4                32/2                   20.04.1996
# ...               ...                          ...
# 1401             3973                   25.07.2018
# 1402             3974                   25.07.2018
# 1404             3976                   27.07.2018
# 1405             3977                   01.08.2018
# 1887             4475                   24.11.2021
#
#      Срок\r\nдействия\r\nсертификата  \
# 0                         2020-01-08
# 1                         2019-06-25
# 2                         2020-05-24
# 3                         2021-04-17
# 4                         2021-04-17
# ...                              ...
# 1401                      2021-07-25
# 1402                      2021-07-25
# ...

# %%
x['data'] = np.where((x['Информация об окончании срока технической поддержки, полученная от заявителя'] == 'бессрочно'), '31.12.2100', x['Информация об окончании срока технической поддержки, полученная от заявителя'])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
x['data'] = np.where((x['Информация об окончании срока технической поддержки, полученная от заявителя'] == 0), '01.01.2000', x['Информация об окончании срока технической поддержки, полученная от заявителя'])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
x['data'] = np.where((x['data'] == 'бессрочно'), '31.12.2100', x['data'])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
x['data'] = x['data'].astype('datetime64')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
x = x.loc[(x['Срок\r\nдействия\r\nсертификата'] < '2022-11-22') & (x['data'] > '2022-11-22')]

# %%
x = x.drop(['data'], axis=1)

# %%
x.head()
# Out:
#    №\r\nсертификата Дата\r\nвнесения\r\nв реестр  \
# 0              17/1                   26.07.2002
# 3              32/1                   20.04.1996
# 4              32/2                   20.04.1996
# 11               66                   26.12.1996
# 24            214/1                   26.07.2002
#
#    Срок\r\nдействия\r\nсертификата  \
# 0                       2020-01-08
# 3                       2021-04-17
# 4                       2021-04-17
# 11                      2021-01-24
# 24                      2020-01-08
#
#                       Наименование\r\nсредства (шифр)  \
# 0   фильтр сетевой помехоподавляющий ФСПК-100(200)...
# 3   система защиты информации от несанкционированн...
# 4   система защиты информации от несанкционированн...
# 11   устройство активной защиты информации «Волна-4М»
# 24  фильтр сетевой помехоподавляющий ФСПК-10-220-9...
#
#    Наименования документов, требованиям которых соответствует средство  \
# ...

# %% [markdown]
# 6. Показать наименования всех средств, которые проходили испытания в частных организациях (форма организации ООО, ЗАО, ПАО, АО).

# %%
df.loc[df['Орган по\r\nсертификации'].str.contains('АО|ООО|ЗАО|ПАО') == True]
# Out:
#      №\r\nсертификата Дата\r\nвнесения\r\nв реестр  \
# 0                17/1                   26.07.2002
# 3                32/1                   20.04.1996
# 4                32/2                   20.04.1996
# 11                 66                   26.12.1996
# 12                 67                   26.12.1996
# ...               ...                          ...
# 1912             4501                   28.12.2021
# 1915             4505                   14.01.2022
# 1920             4513                   19.01.2022
# 1921             4514                   20.01.2022
# 1923             4517                   02.02.2022
#
#      Срок\r\nдействия\r\nсертификата  \
# 0                         01.08.2020
# 3                         17.04.2021
# 4                         17.04.2021
# 11                        24.01.2021
# 12                        24.01.2021
# ...                              ...
# 1912                      28.12.2026
# 1915                      14.01.2027
# ...
